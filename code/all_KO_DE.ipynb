# %% [markdown]
# # Setup

# %%
import scanpy as sc
import scvi
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
import os
import pandas as pd
# Out:
# Global seed set to 0

# %%
sc.set_figure_params(figsize=(4,4),  dpi=150, dpi_save=300, facecolor="white", frameon=False)
sns.set_context("paper")
plt.rcParams["axes.grid"] = False
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
os.getcwd()
# Out:
# '/notebook/Joe/M-cells/code'

# %% [markdown]
# # import data

# %%
adata = sc.read("/notebook/External/Archive/Joe/processed_data/M_cell/h5ad_files/all_KO_3008_genes.h5ad")
model = scvi.model.SCVI.load("/notebook/External/Archive/Joe/processed_data/M_cell/scVI_models/all_KO_3008_genes", adata=adata, use_gpu=True)
# Out:
# INFO     File /notebook/External/Archive/Joe/processed_data/M_cell/scVI_models/all_KO_3008_ge
#          nes/model.pt already downloaded

# %%
adata.obs
# Out:
#                     batch  scrublet_score  scrublet_called_doublet  \
# AAACCCAAGATGTTCC-1  Yi_KO        0.076734                    False
# AAACCCACACTAACCA-1  Yi_KO        0.049195                    False
# AAACCCACACTACGGC-1  Yi_KO        0.062511                    False
# AAACCCAGTACGGGAT-1  Yi_KO        0.158912                    False
# AAACCCAGTAGCACGA-1  Yi_KO        0.080978                    False
# ...                   ...             ...                      ...
# TTTGTTGGTAACACCT-1  Yi_KO        0.115417                    False
# TTTGTTGGTCATGGCC-1  Yi_KO        0.070930                    False
# TTTGTTGGTCGCTGCA-1  Yi_KO        0.076734                    False
# TTTGTTGGTGCCCACA-1  Yi_KO        0.049195                    False
# TTTGTTGTCACTGCTC-1  Yi_KO        0.055354                    False
#
#                     n_genes_by_counts  total_counts  total_counts_mt  \
# AAACCCAAGATGTTCC-1               2945       14353.0            237.0
# ...

# %%
de_df = model.differential_expression(
    groupby="cell_type",
)
# Out:
# DE...: 100%|██████████| 26/26 [00:17<00:00,  1.48it/s]

# %%
de_df
# Out:
#          proba_de  proba_not_de  bayes_factor    scale1        scale2  \
# Reg1       0.9790        0.0210      3.842009  0.000004  3.086628e-05
# Gm30931    0.9772        0.0228      3.757930  0.000049  4.127407e-06
# Hsd3b2     0.9764        0.0236      3.722625  0.000002  7.169330e-07
# Sprr2d     0.9744        0.0256      3.639229  0.000002  7.598281e-05
# Aldh3b2    0.9738        0.0262      3.615446  0.000004  7.372299e-05
# ...           ...           ...           ...       ...           ...
# mt-Co2     0.7130        0.2870      0.909999  0.017694  1.783557e-02
# Srgn       0.7090        0.2910      0.890532  0.017961  1.425528e-02
# mt-Co3     0.6878        0.3122      0.789854  0.018955  1.968978e-02
# Ubd        0.6736        0.3264      0.724513  0.014458  1.253156e-02
# Cd74       0.6460        0.3540      0.601503  0.133672  9.326467e-02
#
#          pseudocounts  delta  lfc_mean  lfc_median   lfc_std  ...   raw_mean1  \
# ...

# %%
markers = {}
cats = adata.obs.cell_type.cat.categories
for i, c in enumerate(cats):
    print(f"Saving {c} DE genes")
    cid = f"{c} vs Rest"
    cell_type_df = de_df.loc[de_df.comparison == cid]
    cell_type_df = cell_type_df[cell_type_df.lfc_mean > 0]
    cell_type_df = cell_type_df[cell_type_df["bayes_factor"] > 2.5]
    cell_type_df = cell_type_df[cell_type_df["non_zeros_proportion1"] > 0.1]
    markers[c] = cell_type_df
    cell_type_df.to_csv(f"/notebook/Joe/M-cells/analysis/DE_all_KO_cell_types/{c}_marker_genes.csv")
# Out:
# Saving Aire+ 2 DE genes
# Saving 1 DE genes
# Saving Late_Post Aire 2 DE genes
# Saving 3 DE genes
# Saving Late_Post Aire 1 DE genes
# Saving Aire+ 1 DE genes
# Saving Tuft DE genes
# Saving Ccl21a+ DE genes
# Saving TAC-TECs DE genes
# Saving 9 DE genes
# Saving 10 DE genes
# Saving 11 DE genes
# Saving 12 DE genes
# Saving 13 DE genes
# Saving 14 DE genes
# Saving 15 DE genes
# Saving 16 DE genes
# Saving 17 DE genes
# Saving 18 DE genes
# Saving 19 DE genes
# Saving 20 DE genes
# Saving 21 DE genes
# Saving 22 DE genes
# Saving 23 DE genes
# Saving 24 DE genes
# Saving 25 DE genes
