# %% [markdown]
# # Setup

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
import scanpy as sc
import seaborn as sns
import scrnatools as rna
import matplotlib.pyplot as plt

# %%
# Setup figure params
plt.rcParams["pdf.use14corefonts"] = True
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = "Arial"
sc.set_figure_params(dpi=80, dpi_save=300, facecolor="white", frameon=False)
sns.set_context("paper")
plt.rcParams["axes.grid"] = False

# %%
warnings.resetwarnings()

# %% [markdown]
# # Data paths

# %%
rawDataPath = "/mnt/iacchus/joe/raw_data/"
processedDataPath = "/mnt/iacchus/joe/processed_data/"

# %%
# rawDataPath = "/mnt/e/Archive/Joe/raw_data/"
# processedDataPath = "/mnt/e/Archive/Joe/processed_data/"

# %% [markdown]
# # Import data

# %%
aire = sc.read(f"{processedDataPath}/Fezf2_thymus_paper/h5ad_files/pairwise_processing/aire_TECs.h5ad")
fezf2 = sc.read(f"{processedDataPath}/Fezf2_thymus_paper/h5ad_files/pairwise_processing/fezf2_TECs.h5ad")

# %% [markdown]
# # Genotype/cell type plots

# %%
sc.settings.figdir = "../../analysis/paper_figures/S5"
sc.pl.umap(
    aire,
    color=["majority_voting"],
    save="_S5A_Aire_cell_types.pdf"
)
sc.pl.umap(
    fezf2,
    color=["majority_voting"],
    save="_S5A_Fezf2_cell_types.pdf"
)
# Out:
# WARNING: saving figure to file ../../analysis/paper_figures/S5/umap_S5A_Aire_cell_types.pdf
# WARNING: saving figure to file ../../analysis/paper_figures/S5/umap_S5A_Fezf2_cell_types.pdf

# %%
sc.settings.figdir = "../../analysis/paper_figures/S5"
sc.pl.umap(
    aire,
    color=["genotype"],
    groups=["Aire_KO"],
    save="_S5A_Aire_KO.pdf",
    palette=["tab:orange"]
)
# Out:
# WARNING: Length of palette colors is smaller than the number of categories (palette length: 1, categories length: 2. Some categories will have the same color.
# WARNING: saving figure to file ../../analysis/paper_figures/S5/umap_S5A_Aire_KO.pdf

# %%
sc.settings.figdir = "../../analysis/paper_figures/S5"
sc.pl.umap(
    fezf2,
    color=["genotype"],
    groups=["Fezf2_KO"],
    save="_S5A_Fezf2_KO.pdf",
    palette=["tab:green"]
)
# Out:
# WARNING: Length of palette colors is smaller than the number of categories (palette length: 1, categories length: 2. Some categories will have the same color.
# WARNING: saving figure to file ../../analysis/paper_figures/S5/umap_S5A_Fezf2_KO.pdf

# %%
sc.settings.figdir = "../../analysis/paper_figures/S5"
sc.pl.umap(
    aire,
    color=["genotype"],
    groups=["WT"],
    save="_S5A_Aire_WT.pdf",
    palette=["tab:blue"]
)
sc.pl.umap(
    fezf2,
    color=["genotype"],
    groups=["WT"],
    save="_S5A_Fezf2_WT.pdf",
    palette=["tab:blue"]
)
# Out:
# WARNING: Length of palette colors is smaller than the number of categories (palette length: 1, categories length: 2. Some categories will have the same color.
# WARNING: saving figure to file ../../analysis/paper_figures/S5/umap_S5A_Aire_WT.pdf
# WARNING: Length of palette colors is smaller than the number of categories (palette length: 1, categories length: 2. Some categories will have the same color.
# WARNING: saving figure to file ../../analysis/paper_figures/S5/umap_S5A_Fezf2_WT.pdf

# %% [markdown]
# # Feature plots
